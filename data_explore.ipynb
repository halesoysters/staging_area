# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = Path('PLACES__County.csv')
county_df = pd.read_csv(data)
county_df
# Out:
#      StateAbbr    StateDesc CountyName  CountyFIPS  TotalPopulation  \
# 0           NJ   New Jersey     Warren       34041           105267
# 1           OK     Oklahoma    Jackson       40065            24530
# 2           IL     Illinois   Lawrence       17101            15678
# 3           KS       Kansas     Barton       20009            25779
# 4           AK       Alaska  Anchorage        2020           288000
# ...        ...          ...        ...         ...              ...
# 3137        KY     Kentucky     Carter       21043            26797
# 3138        MS  Mississippi     DeSoto       28033           184945
# 3139        NY     New York   Richmond       36085           476143
# 3140        KS       Kansas     Saline       20169            54224
# 3141        TX        Texas       Wise       48497            69984
#
#       ACCESS2_CrudePrev ACCESS2_Crude95CI  ACCESS2_AdjPrev ACCESS2_Adj95CI  \
# ...

# %%
#drop unecessary columns
county_pop_df = county_df.filter(['StateDesc', 'CountyName', 'CountyFIPS', 'TotalPopulation', 'ACCESS2_CrudePrev'
                                  'ACCESS2_AdjPrev', 'ARTHRITIS_CrudePrev', 'ARTHRITIS_Adj95CI', 'BINGE_CrudePrev',
                                  'BINGE_AdjPrev', 'BPHIGH_CrudePrev', 'BPHIGH_AdjPrev', 'BPMED_CrudePrev', 'BPMED_AdjPrev',
                                  'CANCER_CrudePrev', 'CANCER_AdjPrev', 'CASTHMA_CrudePrev', 'CASTHMA_AdjPrev', 'CERVICAL_CrudePrev',
                                  'CERVICAL_AdjPrev',  'CHD_CrudePrev', 'CHD_AdjPrev', 'CHECKUP_CrudePrev', 'CHECKUP_AdjPrev', 
                                  'CHOLSCREEN_CrudePrev', 'CHOLSCREEN_AdjPrev', 'COLON_SCREEN_CrudePrev', 'COLON_SCREEN_AdjPrev',
                                  'COPD_CrudePrev','COPD_AdjPrev', 'COREM_CrudePrev', 'COREM_AdjPrev', 'COREW_CrudePrev', 'COREW_AdjPrev',
                                  'CSMOKING_CrudePrev', 'CSMOKING_AdjPrev', 'DENTAL_CrudePrev', 'DENTAL_AdjPrev', 'DEPRESSION_CrudePrev',
                                  'DEPRESSION_AdjPrev', 'DIABETES_CrudePrev', 'DIABETES_AdjPrev', 'GHLTH_CrudePrev', 'GHLTH_AdjPrev',
                                  'HIGHCHOL_CrudePrev', 'HIGHCHOL_AdjPrev', 'KIDNEY_CrudePrev', 'KIDNEY_AdjPrev', 'LPA_CrudePrev', 
                                  'LPA_AdjPrev', 'MAMMOUSE_CrudePrev', 'MAMMOUSE_AdjPrev', 'MHLTH_CrudePrev', 'MHLTH_AdjPrev', 
                                  'OBESITY_CrudePrev', 'OBESITY_AdjPrev', 'PHLTH_CrudePrev', 'PHLTH_AdjPrev', 'SLEEP_CrudePrev', 
                                  'SLEEP_AdjPrev', 'STROKE_CrudePrev', 'STROKE_AdjPrev', 'TEETHLOST_CrudePrev', 'TEETHLOST_AdjPrev',
                                  'Geolocation'], axis = 1)
county_pop_df
# Out:
#         StateDesc CountyName  CountyFIPS  TotalPopulation  \
# 0      New Jersey     Warren       34041           105267
# 1        Oklahoma    Jackson       40065            24530
# 2        Illinois   Lawrence       17101            15678
# 3          Kansas     Barton       20009            25779
# 4          Alaska  Anchorage        2020           288000
# ...           ...        ...         ...              ...
# 3137     Kentucky     Carter       21043            26797
# 3138  Mississippi     DeSoto       28033           184945
# 3139     New York   Richmond       36085           476143
# 3140       Kansas     Saline       20169            54224
# 3141        Texas       Wise       48497            69984
#
#       ARTHRITIS_CrudePrev ARTHRITIS_Adj95CI  BINGE_CrudePrev  BINGE_AdjPrev  \
# 0                     NaN               NaN              NaN            NaN
# 1                    23.5      (22.2, 23.9)             13.6           13.6
# ...

# %%
#create a new column the classifies countries os Rural, micro urban or Urban based on total population
#create a list of conditions
conditions = [
    (county_pop_df['TotalPopulation']<=2500),
    (county_pop_df['TotalPopulation'] >2500) & (county_pop_df['TotalPopulation'] <49999),
    (county_pop_df['TotalPopulation'] >50000), 
]

#create the list of values to assign for each condition
values = ['Rural', 'Micro-Urban', 'Urban']

#create new column and use np.select to assign values
county_pop_df['RuralUrban'] = np.select(conditions, values)

county_pop_df
# Out:
#         StateDesc CountyName  CountyFIPS  TotalPopulation  \
# 0      New Jersey     Warren       34041           105267
# 1        Oklahoma    Jackson       40065            24530
# 2        Illinois   Lawrence       17101            15678
# 3          Kansas     Barton       20009            25779
# 4          Alaska  Anchorage        2020           288000
# ...           ...        ...         ...              ...
# 3137     Kentucky     Carter       21043            26797
# 3138  Mississippi     DeSoto       28033           184945
# 3139     New York   Richmond       36085           476143
# 3140       Kansas     Saline       20169            54224
# 3141        Texas       Wise       48497            69984
#
#       ARTHRITIS_CrudePrev ARTHRITIS_Adj95CI  BINGE_CrudePrev  BINGE_AdjPrev  \
# 0                     NaN               NaN              NaN            NaN
# 1                    23.5      (22.2, 23.9)             13.6           13.6
# ...

# %%
county_pop_df.to_csv('county_pop_df.csv', index=False)

# %%
data = Path('PLACES__Local_data.csv')
local_df = pd.read_csv(data)
local_df.head()
# Out:
#    Year StateAbbr      StateDesc           LocationName DataSource  \
# 0  2019        US  United States                    NaN      BRFSS
# 1  2019        AK         Alaska         Aleutians West      BRFSS
# 2  2019        AK         Alaska  Prince of Wales-Hyder      BRFSS
# 3  2019        AK         Alaska                  Sitka      BRFSS
# 4  2019        AZ        Arizona             Santa Cruz      BRFSS
#
#           Category                                            Measure  \
# 0       Prevention  Current lack of health insurance among adults ...
# 1  Health Outcomes               Obesity among adults aged >=18 years
# 2  Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Outcomes               Obesity among adults aged >=18 years
# 4  Health Outcomes                Stroke among adults aged >=18 years
#
#   Data_Value_Unit          Data_Value_Type  Data_Value  ...  \
# 0               %         Crude prevalence        13.0  ...
# ...

# %%
#drop unecessary columns
local_pop_df = local_df.filter(['Year', 'StateAbbr', 'LocationName', 'TotalPopulation', 'Geolocation'], axis = 1)
local_pop_df
# Out:
#         Year StateAbbr           LocationName  TotalPopulation  \
# 0       2019        US                    NaN        328239523
# 1       2019        AK         Aleutians West             5634
# 2       2019        AK  Prince of Wales-Hyder             6203
# 3       2019        AK                  Sitka             8493
# 4       2019        AZ             Santa Cruz            46498
# ...      ...       ...                    ...              ...
# 187651  2019        WA                 Pierce           904980
# 187652  2019        WI                 Monroe            46253
# 187653  2018        WI              Menominee             4556
# 187654  2019        WV                Jackson            28576
# 187655  2019        WI             Eau Claire           104646
#
#                              Geolocation
# 0                                    NaN
# 1         POINT (-107.825461 52.8107872)
# 2       POINT (-132.7096152 55.50495667)
# 3       POINT (-135.3033492 57.23208595)
# ...

# %%
#create a new column the classifies countries os Rural, micro urban or Urban based on total population
#create a list of conditions
conditions = [
    (local_pop_df['TotalPopulation']<=2500),
    (local_pop_df['TotalPopulation'] >2500) & (local_pop_df['TotalPopulation'] <49999),
    (local_pop_df['TotalPopulation'] >50000), 
]

#create the list of values to assign for each condition
values = ['Rural', 'Micro-Urban', 'Urban']

#create new column and use np.select to assign values
local_pop_df['RuralUrban'] = np.select(conditions, values)

local_pop_df
# Out:
#         Year StateAbbr           LocationName  TotalPopulation  \
# 0       2019        US                    NaN        328239523
# 1       2019        AK         Aleutians West             5634
# 2       2019        AK  Prince of Wales-Hyder             6203
# 3       2019        AK                  Sitka             8493
# 4       2019        AZ             Santa Cruz            46498
# ...      ...       ...                    ...              ...
# 187651  2019        WA                 Pierce           904980
# 187652  2019        WI                 Monroe            46253
# 187653  2018        WI              Menominee             4556
# 187654  2019        WV                Jackson            28576
# 187655  2019        WI             Eau Claire           104646
#
#                              Geolocation   RuralUrban
# 0                                    NaN        Urban
# 1         POINT (-107.825461 52.8107872)  Micro-Urban
# ...

# %%
#change name of column to merge w census df om CountyName
local_pop_df.rename(columns={'LocationName':'CountyName'}, inplace=True)

# %%
local_pop_df.head()
# Out:
#    Year StateAbbr             CountyName  TotalPopulation  \
# 0  2019        US                    NaN        328239523
# 1  2019        AK         Aleutians West             5634
# 2  2019        AK  Prince of Wales-Hyder             6203
# 3  2019        AK                  Sitka             8493
# 4  2019        AZ             Santa Cruz            46498
#
#                         Geolocation   RuralUrban
# 0                               NaN        Urban
# 1    POINT (-107.825461 52.8107872)  Micro-Urban
# 2  POINT (-132.7096152 55.50495667)  Micro-Urban
# 3  POINT (-135.3033492 57.23208595)  Micro-Urban
# 4  POINT (-110.8465934 31.52596855)  Micro-Urban

# %%
data = Path('PLACES__Census.csv')
census_df = pd.read_csv(data)
census_df
# Out:
#       StateAbbr   StateDesc  CountyName  CountyFIPS    TractFIPS  \
# 0            AZ     Arizona    Maricopa        4013   4013422643
# 1            CA  California  Sacramento        6067   6067007402
# 2            AL     Alabama     Madison        1089   1089000201
# 3            AL     Alabama  Montgomery        1101   1101002202
# 4            AL     Alabama      Butler        1013   1013952800
# ...         ...         ...         ...         ...          ...
# 72332        WI   Wisconsin   Milwaukee       55079  55079120101
# 72333        WI   Wisconsin      Barron       55005  55005000300
# 72334        WI   Wisconsin     Ozaukee       55089  55089620100
# 72335        WI   Wisconsin    Waushara       55137  55137960800
# 72336        WI   Wisconsin   Outagamie       55087  55087010100
#
#        TotalPopulation  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0                 5789               11.9      (10.1, 14.0)
# 1                 6180               15.4      (13.5, 17.3)
# ...

# %%
##create a list of conditions
#conditions = [
    #(census_df['TotalPopulation']<=2500),
    #(census_df['TotalPopulation'] >2500) & (census_df['TotalPopulation'] <49999),
    #(census_df['TotalPopulation'] >50000), 
#]

##create the list of values to assign for each condition
#values = ['Rural', 'Micro-Urban', 'Urban']

##create new column and use np.select to assign values
#census_df['RuralUrban'] = np.select(conditions, values)

#census_df

# %%
#census_df = census_df.drop('RuralUrban', axis=1)
#census_df.head()

# %%
#merge DataFrames
merged_df = pd.merge(
    census_df, local_pop_df, how='outer', on=['CountyName']
)
merged_df
# Out:
#          StateAbbr_x StateDesc CountyName  CountyFIPS     TractFIPS  \
# 0                 AZ   Arizona   Maricopa      4013.0  4.013423e+09
# 1                 AZ   Arizona   Maricopa      4013.0  4.013423e+09
# 2                 AZ   Arizona   Maricopa      4013.0  4.013423e+09
# 3                 AZ   Arizona   Maricopa      4013.0  4.013423e+09
# 4                 AZ   Arizona   Maricopa      4013.0  4.013423e+09
# ...              ...       ...        ...         ...           ...
# 18257855         NaN       NaN        NaN         NaN           NaN
# 18257856         NaN       NaN        NaN         NaN           NaN
# 18257857         NaN       NaN        NaN         NaN           NaN
# 18257858         NaN       NaN        NaN         NaN           NaN
# 18257859         NaN       NaN        NaN         NaN           NaN
#
#           TotalPopulation_x  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0                    5789.0               11.9      (10.1, 14.0)
# ...

# %%
merged_df=merged_df.drop(['Year'], axis=1)

# %%
merged_df = merged_df.drop_duplicates(subset=['CountyName'])

merged_df
# Out:
#          StateAbbr_x      StateDesc  CountyName  CountyFIPS     TractFIPS  \
# 0                 AZ        Arizona    Maricopa      4013.0  4.013423e+09
# 54540             CA     California  Sacramento      6067.0  6.067007e+09
# 73560             AL        Alabama     Madison      1089.0  1.089000e+09
# 459960            AL        Alabama  Montgomery      1101.0  1.101002e+09
# 1358520           AL        Alabama      Butler      1013.0  1.013953e+09
# ...              ...            ...         ...         ...           ...
# 18257260          WI      Wisconsin    Kewaunee     55061.0  5.506196e+10
# 18257500          WY        Wyoming    Niobrara     56027.0  5.602796e+10
# 18257560          WY        Wyoming      Weston     56045.0  5.604595e+10
# 18257680          WV  West Virginia        Wirt     54105.0  5.410503e+10
# 18257800         NaN            NaN         NaN         NaN           NaN
#
#           TotalPopulation_x  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# ...

# %%
merged_df.to_csv('merged_df.csv', index=False)

# %%
plt.scatter(census_df['CHOLSCREEN_CrudePrev'], census_df['HIGHCHOL_CrudePrev'], color = 'blue')

# %%
plt.scatter(census_df['SLEEP_CrudePrev'], census_df['KIDNEY_CrudePrev'], color = 'blue')

# %%
plt.scatter(census_df['DEPRESSION_CrudePrev'], census_df['CSMOKING_CrudePrev'], color = 'blue')
